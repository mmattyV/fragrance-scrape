# %% [markdown]
# #### 1. Crear un Repositorio en GitHub
#
# Pasos:
#
# Repository name: Aroma
# Description (opcional): "Proyecto de recolección y análisis de datos de perfumes"
# Initialize this repository with a README: Marca esta opción.

# %% [markdown]
# #### 2. Crear un Nuevo Environment con Python 3.11.7 y Otros Componentes
# Nombre del Environment: Aroma
#
# Pasos:
#
# Crear el Archivo environment.yaml:
#
# Abre un editor de texto (por ejemplo, Notepad, Visual Studio Code, etc.).
# Copia y pega el contenido de configuración del archivo environment.yaml en el editor.
# Guarda este archivo en un lugar accesible con el nombre environment.yaml.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Activar el Environment:
#
# Abre tu terminal o Anaconda Prompt y ejecuta los siguientes comandos:

# %% [markdown]
# ![image.png](attachment:image.png)
#    yml o yaml, depende del nombre que tiene

# %% [markdown]
# #### 4. Crear la Estructura de Carpetas:
#
# Desde la terminal, navega al directorio del proyecto y ejecuta los siguientes comandos para crear las carpetas necesarias:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 5. Inicializar el Repositorio de Git:
#
# Navega al directorio del proyecto y ejecuta los siguientes comandos:
#
# ![image.png](attachment:image.png)
#
# Conectar el repositorio local con el repositorio remoto:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 6. Crear el archivo test_libraries.py
# en el directorio "src" .

# %% [markdown]
# #### 7. Crear script install_modules.py,
#
# ejecutar script desde su ubicacion (directorio "src")
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 8. Ejecutar test_libraries.py desde su directorio
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 9. Verificación de la Ejecución de Selenium
#
# Si chromedriver y selenium están configurados correctamente, deberías ver una salida indicando que Selenium ha funcionado correctamente, como esta:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 10. Activar entorno
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 11, Verificar la instalacion de las Bibliotecas.

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\miufa\anaconda3\envs\Aroma:
# #
# # Name                    Version                   Build  Channel
# anyio                     4.2.0           py311haa95532_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0          py311h2bbff1b_0
# asttokens                 2.0.5              pyhd3eb1b0_0
# async-lru                 2.0.4           py311haa95532_0
# attrs                     23.1.0          py311haa95532_0
# babel                     2.11.0          py311haa95532_0
# beautifulsoup4            4.12.3          py311haa95532_0
# blas                      1.0                         mkl
# bleach                    4.1.0              pyhd3eb1b0_0
# bottleneck                1.3.7           py311hd7041d2_0
# brotli-python             1.0.9           py311hd77b12b_8
# bzip2                     1.0.8                h2bbff1b_6
# ca-certificates           2024.3.11            haa95532_0
# ...

# %% [markdown]
# #### 12. Documentar y Ejecutar el Script de Prueba

# %%
import numpy as np
from lxml import etree
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import requests
from bs4 import BeautifulSoup
import chromedriver_autoinstaller

# Comprobando Numpy
print("Numpy version:", np.__version__)
array = np.array([1, 2, 3])
print("Numpy array:", array)

# Comprobando lxml
root = etree.Element("root")
etree.SubElement(root, "child").text = "This is a test."
print("lxml is working, generated XML:")
print(etree.tostring(root, pretty_print=True).decode())

# Configurar opciones de Chrome
chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument('--headless')  # Asegurar que la GUI esté apagada
# chrome_options.add_argument('--no-sandbox')
# chrome_options.add_argument('--disable-dev-shm-usage')

# Configurar el path a chromedriver usando chromedriver_autoinstaller
chromedriver_autoinstaller.install()

# Comprobando Selenium
try:
    # Inicializar el driver de Chrome
    driver = webdriver.Chrome(options=chrome_options)
    
    # Navegar a la página de Python
    driver.get("https://www.python.org")
    title = driver.title
    driver.quit()
    print("Selenium is working. Title of python.org is:", title)
except Exception as e:
    print("Selenium encountered an error:", str(e))

# Comprobando Pandas
df = pd.DataFrame({'column1': [1, 2], 'column2': [3, 4]})
print("Pandas DataFrame:")
print(df)

# Comprobando Requests
response = requests.get("https://www.python.org")
print("Requests status code:", response.status_code)

# Comprobando BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
print("BeautifulSoup parsed title:", soup.title.string)
# Out:
# Numpy version: 1.26.4
# Numpy array: [1 2 3]
# lxml is working, generated XML:
# <root>
#   <child>This is a test.</child>
# </root>
#
# Selenium is working. Title of python.org is: Welcome to Python.org
# Pandas DataFrame:
#    column1  column2
# 0        1        3
# 1        2        4
# Requests status code: 200
# BeautifulSoup parsed title: Welcome to Python.org

# %% [markdown]
# 26.06.
#
# pip list  (en bash)
#
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
